# %%
import pandas as pd
import matplotlib.pyplot as plt
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('max_colwidth', 800)
pd.set_option('display.width', 1000)

# %%
# Basic Data Types
basic_data_types = pd.read_csv(r"Data\data type.csv")
basic_data_types
# Out:
#     type           set of values common operatprs
# 0    int                integers      + - // % **
# 1  float  floating point numbers       + - / % **
# 2   bool    true or false values       and or not
# 3    str  sequence of characters              \t+

# %%
# Boolean Values
bool1 = pd.read_csv(r"Data\bool1.csv")
bool2 = pd.read_csv(r"Data\bool2.csv")

# %%
bool1
# Out:
#        a   not a
# 0   True   False
# 1  False    True

# %%
bool2
# Out:
#        a       b  a and b  a or b
# 0   True    True     True    True
# 1   True   False    False    True
# 2  False    True    False    True
# 3  False   False    False   False

# %%
# Comparative operators
comparative_ops = pd.read_csv(r"Data\Comparative operators.csv")
comparative_ops
# Out:
#    op                 meaning     true  false
# 0  ==                   equal     2==2   2==3
# 1  !=               not equal     2!=3   2!=2
# 2   <               less than   2 < 13    2<2
# 3  <=       lss tahn or equal     2<=2   3<=2
# 4   >            greater than     13>2   2>13
# 5  >=   greater than or equal     3>=2   2>=3

# %%
# Quiz:
# Get an input year from the user and decide wether its is a leap year or not?
# HINT: A year is a leap when it's divideable with 4, and not dividable with 100 or it's divideable with 400.

# %%
year = input("please enter a year:")
year = int(year)
# Out:
# please enter a year: 1

# %%
cond1 = year % 4 == 0
cond2 = year % 100 != 0
cond3 = year % 400 == 0

# %%
result = cond1 and cond2 or cond3

# %%
result
# Out:
# False

# %%
# String Methods:
str_methods = pd.read_csv(r"Data\str methods.csv")
str_methods
# Out:
#            Method                                                                                     Description
# 0     capitalize()                                                     Converts the first character to upper case
# 1       casefold()                                                                Converts string into lower case
# 2         center()                                                                      Returns a centered string
# 3          count()                               Returns the number of times a specified value occurs in a string
# 4         encode()                                                       Returns an encoded version of the string
# 5       endswith()                                       Returns true if the string ends with the specified value
# 6     expandtabs()                                                                Sets the tab size of the string
# ...

# %%
plt.figure(figsize=(20, 20))
img0 = plt.imread(r"Data\img0.jpg")
plt.imshow(img0)
plt.axis('off')
plt.show()

# %%
# Quiz: Draw This:
ruler1 = '1'
ruler2 = ruler1 + ' 2 ' + ruler1
ruler3 = ruler2 + ' 3 ' + ruler2
ruler4 = ruler3 + ' 4 ' + ruler3
print(f"{ruler1:^25}")
print(f"{ruler2:^25}")
print(f"{ruler3:^25}")
print(f"{ruler4:^25}")
# Out:
#             1
#           1 2 1
#       1 2 1 3 1 2 1
# 1 2 1 3 1 2 1 4 1 2 1 3 1 2 1

# %%
# built-in functions:
print("Hello World!")
# Out:
# Hello World!

# %%
len("Hello World!")
# Out:
# 12

# %%
type("Hello World!")
# Out:
# str

# %%
abs(-2.3)
# Out:
# 2.3

# %%
str(1.2)
# Out:
# '1.2'

# %%
int('1')
# Out:
# 1

# %%
float('1.2')
# Out:
# 1.2

# %%
int(1.2)
# Out:
# 1

# %%
max(1,2)
# Out:
# 2

# %%
min(1,2)
# Out:
# 1

# %%
# Standard Libraries

# %%
import math

# %%
math.ceil(1.2)
# Out:
# 2

# %%
math.floor(1.2)
# Out:
# 1

# %%
# sin:
math.sin(0)
# Out:
# 0.0

# %%
# cos:
math.cos(0)
# Out:
# 1.0

# %%
# math.asin()
# math.acos()

# %%
import random

# %%
random.random()
# Out:
# 0.8022853675210486

# %%
random.randint(1, 10)
# Out:
# 1

# %%
random.randrange(1, 10)
# Out:
# 4

# %%
# External Libraries:
# Libraries which will be installed seperately by user

# %%
# Data Type Conversion:
# 1. Explicit:
# a: str(), b: int(), c:floor(), bool()

# 2. Implicit:
# 10 / 4.0

# %%
# Basic Data Structures in Python:
data_structures = pd.read_csv(r"Data\data structures.csv")
data_structures
# Out:
#   Data Structure                                                      Description  Mutable?  Ordered?
# 0           List          A list is a collection which is ordered and changeable.      True      True
# 1          Tuple    Tuples are used to store multiple items in a single variable.     False      True
# 2   Dictionaries   Dictionaries are used to store data values in key:value pairs.      True       NaN
# 3            Set      Sets are used to store multiple items in a single variable.      True     False

# %%
# List methods:
lists_methods = pd.read_csv(r"Data\list methods.csv")
lists_methods
# Out:
#        Method                                                                    Description
# 0    append()                                         Adds an element at the end of the list
# 1     clear()                                         Removes all the elements from the list
# 2      copy()                                                     Returns a copy of the list
# 3     count()                        Returns the number of elements with the specified value
# 4    extend()   Add the elements of a list (or any iterable); to the end of the current list
# 5     index()                Returns the index of the first element with the specified value
# 6    insert()                                      Adds an element at the specified position
# 7       pop()                                  Removes the element at the specified position
# 8    remove()                                      Removes the item with the specified value
# ...

# %%
# Dictionary Methods:
dict_methods = pd.read_csv(r"Data\dictionary methods.csv")
dict_methods
# Out:
#       Method                                                Description
# 0    clear()               Removes all the elements from the dictionary
# 1     copy()                           Returns a copy of the dictionary
# 2      get()                     Returns the value of the specified key
# 3    items()  Returns a list containing a tuple for each key value pair
# 4     keys()            Returns a list containing the dictionary's keys
# 5      pop()                 Removes the element with the specified key
# 6  popitem()                   Removes the last inserted key-value pair
# 7   update()  Updates the dictionary with the specified key-value pairs
# 8   values()         Returns a list of all the values in the dictionary

# %%
# Tuple Methods:
tuple_methods = pd.read_csv(r"Data\tuple methods.csv")
tuple_methods
# Out:
#     Method                                                                              Description
# 0  count()                          Returns the number of times a specified value occurs in a tuple
# 1  index()  Searches the tuple for a specified value and returns the position of where it was found

# %%
# Set Methods:
set_methods = pd.read_csv(r"Data\set methods.csv")
set_methods
# Out:
#                            Method                                                                    Description
# 0                           add()                                                     Adds an element to the set
# 1                         clear()                                          Removes all the elements from the set
# 2                          copy()                                                      Returns a copy of the set
# 3                    difference()               Returns a set containing the difference between two or more sets
# 4             difference_update()  Removes the items in this set that are also included in another specified set
# 5                       discard()                                                      Remove the specified item
# 6                  intersection()                     Returns a set that is the intersection of two or more sets
# ...

# %%
# Flow Control:
plt.figure(figsize=(20, 20))
img1 = plt.imread(r"Data\img1.jpg")
plt.imshow(img1)
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(20, 20))
img2 = plt.imread(r"Data\img2.jpg")
plt.imshow(img2)
plt.axis('off')
plt.show()

# %%
plt.figure(figsize=(20, 20))
img3 = plt.imread(r"Data\img3.jpg")
plt.imshow(img3)
plt.axis('off')
plt.show()

# %%
# Quiz2:
# Write a program that gets an input number from user and returns its abs:
n = input('Please enter a number:')
n = int(n)
if n < 0:
    n = -n
print(n)
# Out:
# Please enter a number: 1
# 1

# %%
# Quiz3:
# Write a program that gets two value from users and prints the maximum:
n1 = input("Please enter first number:")
n2 = input("Please Enter second number:")
n1 = int(n1)
n2 = int(n2)
print("Maximum:")
if n1 > n2:
    print(n1)
else:
    print(n2)
# Out:
# Please enter first number: 1
# Please Enter second number: 1
# Maximum:
# 1

# %%
# Quiz4:
# Simulating head or tail:
import random
if random.randint(0, 1) == 0:
    print("Head")
else:
    print("Tail")
# Out:
# Head

# %%
# Quiz5:
# put x and y in sorted order:
n1 = input("Please enter first number:")
n2 = input("Please Enter second number:")
n1 = int(n1)
n2 = int(n2)
if n1 > n2:
    temp = n1
    n1 = n2
    n2 = temp
print(n1, n2)
# Out:
# Please enter first number: 1
# Please Enter second number: 1
# 1 1

# %%
# Quiz6:
# Error check for remainder operation:
n1 = input("Please enter first number:")
n2 = input("Please Enter second number:")
n1 = int(n1)
n2 = int(n2)
if n2 == 0:
    print("Division by Zero")
else:
    print(f"Remainder = {n1 % n2}")
# Out:
# Please enter first number: 1
# Please Enter second number: 1
# Remainder = 0

# %%
# The importance of indentation
n1 = input("Please enter first number:")
n1 = int(n1)
if n1 >= 0:
    print('Not ', end='')
print('Negative')
# Out:
# Please enter first number: 1
# Not Negative

# %% [markdown]
# # The importance of indentation
# n1 = input("Please enter first number:")
# n1 = int(n1)
# if n1 >= 0:
#     print('Not ', end='')
#     print('Negative')

# %%
plt.figure(figsize=(20, 20))
img4 = plt.imread(r"Data\img4.jpg")
plt.imshow(img4)
plt.axis('off')
plt.show()

# %%
print('1st Hello!')
print('2nd Hello!')
print('3rd Hello!')
i = 4
while i <= 10:
    print(f"{i}th Hello!")
    i += 1
# Out:
# 1st Hello!
# 2nd Hello!
# 3rd Hello!
# 4th Hello!
# 5th Hello!
# 6th Hello!
# 7th Hello!
# 8th Hello!
# 9th Hello!
# 10th Hello!

# %%
# A common mistake: forgetting the command to increase the loop counter

# %%
# Quiz:
# Print powers of number 2
n = int(input("How many powers?"))
i = 0
power = 1
while i <= n:
    print(f"2 ** {i} = {power}")
    i += 1
    power *= 2
# Out:
# How many powers? 1
# 2 ** 0 = 1
# 2 ** 1 = 2

# %%
print('1st Hello!')
print('2nd Hello!')
print('3rd Hello!')
for i in range(4, 11):
    print(f"{i}th Hello!")
# Out:
# 1st Hello!
# 2nd Hello!
# 3rd Hello!
# 4th Hello!
# 5th Hello!
# 6th Hello!
# 7th Hello!
# 8th Hello!
# 9th Hello!
# 10th Hello!

# %%
# Quiz:
n = int(input("How many powers?"))
power = 1
for i in range(n+1):
    print(f"2 ** {i} = {power}")
    power *= 2
# Out:
# How many powers? 1
# 2 ** 0 = 1
# 2 ** 1 = 2

# %%
# Quiz:
n = int(input("How many rules?"))
ruler = ' '
for i in range(1, n+1):
    ruler = ruler + str(i) + ruler
print(ruler)
# Out:
# How many rules? 1
#  1

# %%
# Quiz:
# Computer a finite sum:
n = int(input("How many numbers?"))
total = 0
for i in range(1, n+1):
    total += i
total
# Out:
# How many numbers? 1
# 1

# %%
# Quiz:
# Compute finite product(factorial)
n = int(input("How many numbers?"))
product = 1
for i in range(1, n+1):
    product *= i
product
# Out:
# How many numbers? 1
# 1

# %%
plt.figure(figsize=(8, 8))
img5 = plt.imread(r"Data\img5.jpg")
plt.imshow(img5)
plt.axis('off')
plt.show()

# %%
# Quiz: Compute Tax Rate:
income = int(input("What is your income?"))
rate = "I don't know"
if income < 8925:
    rate = 0
else:
    if income < 8925:
        rate = .1
    else:
        if income < 36250:
            rate = .15
print(rate)
# Out:
# What is your income? 1
# 0

# %%
income = int(input("What is your income?"))
rate = "I don't know"
if income < 0:
    rate = 0
elif income < 8925:
    rate = .1
elif income < 36250:
    rate = .15
elif income < 87850:
    rate = 23
print(rate)
# Out:
# What is your income? 1
# 0.1

# %%
income = int(input("What is your income?"))
rate = "I don't know"
if income < 0: rate = 0
elif income < 8925: rate = .1
elif income < 36250: rate = .15
elif income < 87850: rate = 23
print(rate)
# Out:
# What is your income? 1
# 0.1

# %%
# Harmonic Series:
n = int(input("Enter n:"))
total = 0
for i in range(1, n+1):
    total += 1.0 / i
total
# Out:
# Enter n: 1
# 1.0

# %%
# Binary number
n = int(input("Enter n:"))
v = 1
while v <= n // 2:
    v *= 2
while v > 0:
    if n < v:
        print(0, end='')
    else:
        print(1, end='')
        n -= v
    v //= 2
print()
# Out:
# Enter n: 1
# 1

# %%
plt.figure(figsize=(20, 20))
excersise1 = plt.imread(r"Data\Excersise1.jpg")
plt.imshow(excersise1)
plt.axis('off')
plt.show()
